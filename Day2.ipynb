# %%
import pandas as pd
data= pd.read_csv("https://raw.githubusercontent.com/Nameera05/Datasets/main/Sleep_Efficiency1.csv")

# %%
data
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_wikipedia(topic):

  url = f'https://en.wikipedia.org/wiki/{topic}'
  response = requests.get(url)

  soup = BeautifulSoup(response.text,'html.parser')
  paragraphs=soup.find_all('p')
  for paragraph in paragraphs:
    print(paragraph.get_text())

user_input = input("enter a topic :")
scrape_wikipedia(user_input)
# Out:
# enter a topic :fatima
#
#
# Fatima bint Muhammad (Arabic: فَاطِمَة بِنْت مُحَمَّد, romanized: Fāṭima bint Muḥammad; 605/15–632 CE), commonly known as Fatima al-Zahra' (Arabic: فَاطِمَة ٱلزَّهْرَاء, romanized: Fāṭima al-Zahrāʾ), was the daughter of the Islamic prophet Muhammad and his wife Khadija.[1] Fatima's husband was Ali, the fourth of the Rashidun Caliphs and the first Shia Imam. Fatima's sons were Hasan and Husayn, the second and third Shia Imams, respectively.[2][3] Fatima has been compared to Mary, mother of Jesus, especially in Shia Islam.[4][5] Muhammad is said to have regarded her as the best of women[6][7] and the dearest person to him.[8][6] She is often viewed as an ultimate archetype for Muslim women and an example of compassion, generosity, and enduring suffering.[4] It is through Fatima that Muhammad's family line has survived to this date.[9][7] Her name and her epithets remain popular choices for Muslim girls.[10][11]
#
# ...

# %% [markdown]
# preprocessing

# %%
import pandas as pd

dfs= pd.read_html('https://en.wikipedia.org/wiki/Continent')
dfs[1]
# Out:
#        Continent  Land area                           Population
#        Continent        km2     sq mi % of world 2021 (estimate) % of world
# 0          Earth  149733926  57812592       100%      7909295151        NaN
# 1           Asia   44614000  17226000      29.8%      4694576167        NaN
# 2         Africa   30365000  11724000      20.3%      1393676444        NaN
# 3  North America   24230000   9360000      16.2%       595783465        NaN
# 4  South America   17814000   6878000      11.9%       434254119        NaN
# 5     Antarctica   14200000   5500000       9.5%               0        NaN
# 6         Europe   10000000   3900000       6.7%       745173774        NaN
# 7       Oceania†    8510926   3286087       5.7%        44491724        NaN

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=452, step=1),
#  Index(['ID', 'Age', 'Gender', 'Sleep duration', 'Sleep efficiency',
#         'REM sleep percentage', 'Deep sleep percentage',
#         'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#         'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#        dtype='object')]

# %%
data.shape
# Out:
# (452, 13)

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Sleep duration', 'Sleep efficiency',
#        'REM sleep percentage', 'Deep sleep percentage',
#        'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#        'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#       dtype='object')

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 5876

# %%
data.dtypes
# Out:
# ID                          int64
# Age                         int64
# Gender                     object
# Sleep duration            float64
# Sleep efficiency          float64
# REM sleep percentage        int64
# Deep sleep percentage       int64
# Light sleep percentage      int64
# Awakenings                float64
# Caffeine consumption      float64
# Alcohol consumption       float64
# Smoking status             object
# Exercise frequency        float64
# dtype: object

# %%
data.isna().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
data.isnull()
# Out:
#         ID    Age  Gender  Sleep duration  Sleep efficiency  \
# 0    False  False   False           False             False
# 1    False  False   False           False             False
# 2    False  False   False           False             False
# 3    False  False   False           False             False
# 4    False  False   False           False             False
# ..     ...    ...     ...             ...               ...
# 447  False  False   False           False             False
# 448  False  False   False           False             False
# 449  False  False   False           False             False
# 450  False  False   False           False             False
# 451  False  False   False           False             False
#
#      REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# 0                   False                  False                   False
# 1                   False                  False                   False
# ...

# %%
data.count()
# Out:
# ID                        452
# Age                       452
# Gender                    452
# Sleep duration            452
# Sleep efficiency          452
# REM sleep percentage      452
# Deep sleep percentage     452
# Light sleep percentage    452
# Awakenings                432
# Caffeine consumption      427
# Alcohol consumption       438
# Smoking status            452
# Exercise frequency        446
# dtype: int64

# %%
data.values
# Out:
# array([[1, 65, 'Female', ..., 0.0, 'Yes', 3.0],
#        [2, 69, 'Male', ..., 3.0, 'Yes', 3.0],
#        [3, 40, 'Female', ..., 0.0, 'No', 3.0],
#        ...,
#        [450, 40, 'Female', ..., 3.0, 'Yes', 0.0],
#        [451, 45, 'Male', ..., 0.0, 'No', 3.0],
#        [452, 18, 'Male', ..., 0.0, 'No', 1.0]], dtype=object)

# %%
data.head(5)
# Out:
#    ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0   1   65  Female             6.0              0.88                    18
# 1   2   69    Male             7.0              0.66                    19
# 2   3   40  Female             8.0              0.89                    20
# 3   4   40  Female             6.0              0.51                    23
# 4   5   57    Male             8.0              0.76                    27
#
#    Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                     70                      12         0.0
# 1                     28                      53         3.0
# 2                     70                      10         1.0
# 3                     25                      52         3.0
# 4                     55                      18         3.0
#
#    Caffeine consumption  Alcohol consumption Smoking status  \
# 0                   0.0                  0.0            Yes
# ...

# %%
data[data["Sleep duration"]>8.0]
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 7      8   53    Male            10.0              0.90                    28
# 9     10   11  Female             9.0              0.55                    18
# 12    13   30  Female             9.0              0.93                    24
# 13    14   28    Male             8.5              0.64                    28
# 14    15   36  Female             8.5              0.54                    20
# ..   ...  ...     ...             ...               ...                   ...
# 413  414   51    Male             8.5              0.88                    28
# 418  419   51    Male             9.0              0.66                    22
# 419  420   21    Male             8.5              0.87                    19
# 441  442   46    Male             9.0              0.60                    23
# 449  450   40  Female             8.5              0.55                    20
#
# ...

# %%
data_EF= data.groupby(["Age"])[["Sleep duration"]]

# %%
data['Alcohol consumption'].mean()
# Out:
# 1.17351598173516

# %%
data['Alcohol consumption'].fillna(1.1735,inplace=True)

# %%
data['Caffeine consumption'].mean()
# Out:
# 23.653395784543324

# %%
data['Caffeine consumption'].fillna(23.6533,inplace=True)

# %%
data['Awakenings'].mean()
# Out:
# 1.6412037037037037

# %%
data['Awakenings'].fillna(1.6412,inplace=True)

# %%
data.isna().sum()
# Out:
# ID                        0
# Age                       0
# Gender                    0
# Sleep duration            0
# Sleep efficiency          0
# REM sleep percentage      0
# Deep sleep percentage     0
# Light sleep percentage    0
# Awakenings                0
# Caffeine consumption      0
# Alcohol consumption       0
# Smoking status            0
# Exercise frequency        6
# dtype: int64

# %%
from sklearn import preprocessing

le=preprocessing.LabelEncoder()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      228
# Female    224
# Name: count, dtype: int64

# %%
data["Gender"]=le.fit_transform(data["Gender"])

# %%
data["Gender"].value_counts()
# Out:
# Gender
# 1    228
# 0    224
# Name: count, dtype: int64

# %%
data['Smoking status'].value_counts()
# Out:
# Smoking status
# 0    298
# 1    154
# Name: count, dtype: int64

# %%
data["Smoking status"]=le.fit_transform(data["Smoking status"])

# %%
data['Smoking status'].value_counts()
# Out:
# Smoking status
# 0    298
# 1    154
# Name: count, dtype: int64
